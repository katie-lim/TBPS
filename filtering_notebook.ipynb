# %%
from data_tools import *
filepath = "./data/total_dataset.pkl"

total_dataset = load_dataset(filepath)

# filter out data. Where we are not certain that the mu plus/minus are muons, the K is a kaon, (etc) those rows are filtered.
# Rows where the particles do not meet a certain criteria are also filtered using their chi-squared and other values.
filtered_dataset = filter_dataset(total_dataset)
# Out:
# c:\Users\Katie\Documents\TBPS\data_tools.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pf_df[i[0]][pf_df[i[0]] < 0] = 0
# c:\Users\Katie\Documents\TBPS\data_tools.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pf_df[i[1]][pf_df[i[1]] < 0] = 0
# c:\Users\Katie\Documents\TBPS\data_tools.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pf_df[i[2]][pf_df[i[2]] < 0] = 0
# ...

# %%
filtered_dataset
# Out:
#         mu_plus_MC15TuneV1_ProbNNk  mu_plus_MC15TuneV1_ProbNNpi  \
# 12                        0.000030                     0.028917
# 14                        0.000110                     0.183072
# 15                        0.000079                     0.125044
# 17                        0.004149                     0.041732
# 18                        0.002081                     0.091886
# ...                            ...                          ...
# 498336                    0.000044                     0.038109
# 498344                    0.000079                     0.029020
# 498346                    0.000730                     0.264272
# 498348                    0.000066                     0.035032
# 498354                    0.000345                     0.008908
#
#         mu_plus_MC15TuneV1_ProbNNmu  mu_plus_MC15TuneV1_ProbNNe  \
# 12                         0.998759                3.632477e-06
# 14                         0.988902                3.963066e-07
# ...

# %%
bins = split_into_bins(filtered_dataset)

# %%
bins[6]
# Out:
#         mu_plus_MC15TuneV1_ProbNNk  mu_plus_MC15TuneV1_ProbNNpi  \
# 507                       0.000796                     0.027275
# 1364                      0.002968                     0.008136
# 1490                      0.000056                     0.001326
# 2234                      0.000138                     0.087636
# 4779                      0.048206                     0.258399
# ...                            ...                          ...
# 492848                    0.000236                     0.035497
# 493171                    0.002462                     0.014423
# 493884                    0.006268                     0.589252
# 495267                    0.000804                     0.009230
# 497787                    0.154157                     0.019085
#
#         mu_plus_MC15TuneV1_ProbNNmu  mu_plus_MC15TuneV1_ProbNNe  \
# 507                        0.999855                9.463130e-07
# 1364                       0.997027                2.723025e-06
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(bins[3]['costhetal'], bins=25, density=True)
plt.xlabel(r'$cos(\theta_l)$')
plt.ylabel(r'Number of candidates')
plt.grid()
plt.show()
