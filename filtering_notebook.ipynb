# %%
from data_tools import *
filepath = "./data/total_dataset.pkl"

total_dataset = load_dataset(filepath)

# filter out data where we are not certain that the mu plus/minus are muons, the K is a kaon, etc
filtered_dataset = filter_dataset_by_particles(total_dataset)

# %%
filtered_dataset
# Out:
#         mu_plus_MC15TuneV1_ProbNNk  mu_plus_MC15TuneV1_ProbNNpi  \
# 3                         0.001732                     0.415623
# 6                         0.017114                     0.020222
# 9                         0.000062                     0.040671
# 17                        0.025416                     0.038225
# 19                        0.000763                     0.191866
# ...                            ...                          ...
# 499904                    0.000081                     0.003751
# 499906                    0.000106                     0.012839
# 499924                    0.001012                     0.016455
# 499930                    0.000575                     0.148390
# 499945                    0.000889                     0.275274
#
#         mu_plus_MC15TuneV1_ProbNNmu  mu_plus_MC15TuneV1_ProbNNe  \
# 3                          0.978096                1.223794e-05
# 6                          0.995811                9.273053e-06
# ...

# %%
# remove data where the particles do not meet at a vertex
filtered_dataset = filter_dataset_by_common_vertex(filtered_dataset)

# %%
filtered_dataset
# Out:
#         mu_plus_MC15TuneV1_ProbNNk  mu_plus_MC15TuneV1_ProbNNpi  \
# 37                        0.000084                     0.000352
# 105                       0.000091                     0.032180
# 165                       0.000081                     0.004614
# 170                       0.000623                     0.035179
# 210                       0.000608                     0.075020
# ...                            ...                          ...
# 499749                    0.000210                     0.071506
# 499816                    0.000076                     0.007099
# 499860                    0.000443                     0.003581
# 499891                    0.000078                     0.019457
# 499930                    0.000575                     0.148390
#
#         mu_plus_MC15TuneV1_ProbNNmu  mu_plus_MC15TuneV1_ProbNNe  \
# 37                         0.999793                3.369690e-06
# 105                        0.995111                9.145585e-07
# ...
